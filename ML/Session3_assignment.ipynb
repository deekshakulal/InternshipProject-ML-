# %%
import pandas as pd

# %%
l=r'C:\Users\dell\Documents\pincore\SUV_CAR.csv'
ds=pd.read_csv(l)
print(ds)
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# 5     27            58000          0
# 6     27            84000          0
# 7     32           150000          1
# 8     25            33000          0
# 9     35            65000          0
# 10    26            80000          0
# 11    26            52000          0
# 12    20            86000          0
# 13    32            18000          0
# 14    18            82000          0
# 15    29            80000          0
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# 20    45            22000          1
# 21    47            49000          1
# 22    48            41000          1
# 23    45            22000          1
# ...

# %%
print(ds.head())
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
print(ds.tail())
# Out:
#      Age  EstimatedSalary  Purchased
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1

# %%
print(ds.shape)
# Out:
# (400, 3)

# %%
print(ds.describe())
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000

# %%
print(ds.dtypes)
# Out:
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# dtype: object

# %%
print(ds.describe)
# Out:
# <bound method NDFrame.describe of      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# 5     27            58000          0
# 6     27            84000          0
# 7     32           150000          1
# 8     25            33000          0
# 9     35            65000          0
# 10    26            80000          0
# 11    26            52000          0
# 12    20            86000          0
# 13    32            18000          0
# 14    18            82000          0
# 15    29            80000          0
# 16    47            25000          1
# 17    45            26000          1
# 18    46            28000          1
# 19    48            29000          1
# 20    45            22000          1
# 21    47            49000          1
# 22    48            41000          1
# ...

# %%
print(ds.groupby('Age').size())
# Out:
# Age
# 18     5
# 19     7
# 20     7
# 21     4
# 22     5
# 23     6
# 24     9
# 25     6
# 26    16
# 27    13
# 28    12
# 29    10
# 30    11
# 31    11
# 32     9
# 33     9
# 34     6
# 35    32
# 36    12
# 37    20
# 38    13
# 39    15
# 40    15
# 41    16
# 42    16
# 43     3
# 44     2
# 45     7
# 46    12
# 47    14
# 48    14
# 49    10
# 50     4
# 51     3
# 52     6
# 53     5
# 54     4
# 55     3
# 56     3
# 57     5
# 58     6
# 59     7
# 60     7
# dtype: int64

# %%
print(ds.groupby('Age'))

# %%
print(ds.groupby('Purchased').size())
# Out:
# Purchased
# 0    257
# 1    143
# dtype: int64

# %%
import matplotlib.pyplot as plt 
ds.plot(subplots=True,layout=(2,2))
plt.show()

# %%
ds.plot(kind="box",subplots=True,layout=(2,2))
plt.show()

# %%
#UNIVARIATE VISUALIZATION
ds.plot(subplots=True,layout=(2,2),sharex=False,sharey=False) # share y and x values 
plt.show()

# %%
#UNIVARIATE VISUALIZATION
ds.plot(subplots=True,layout=(3,2),sharex=False,sharey=False) # share y and x values 
plt.show()

# %%
#BOX
ds.plot(kind="box",subplots=True,layout=(2,2),sharex=True,sharey=True) # share y and x values 
plt.show()

# %%
#BOX
ds.plot(kind="box",subplots=True,layout=(2,2)) # share y and x values 
plt.show()

# %%
#BOX
ds.plot(kind="box",subplots=True,layout=(2,2),sharex=True,sharey=False) # share y and x values 
plt.show()

# %%
ds.plot(kind="box",subplots=False,layout=(2,2)) # share y and x values 
plt.show()

# %%
ds.plot(kind="box",subplots=False,layout=(2,2),sharex=True,sharey=False) # share y and x values 
plt.show()
